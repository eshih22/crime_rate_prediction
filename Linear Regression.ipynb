# %%
# Import required libraries
import numpy as np
import pandas as pd
import hvplot.pandas
from pathlib import Path
from sklearn.linear_model import LinearRegression
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# Read salary data
file_path = Path("All_data_cleaned.csv")
crime = pd.read_csv(file_path)

# Display sample data
crime.head()
# Out:
#    Year          City  \
# 0  2015       Alameda
# 1  2015      Alhambra
# 2  2015       Anaheim
# 3  2015   Bakersfield
# 4  2015  Baldwin Park
#
#    Percent Population 25 years and over - Less than 9th grade  \
# 0                                                3.6
# 1                                                8.3
# 2                                               14.4
# 3                                               10.6
# 4                                               22.1
#
#    Percent Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                3.6
# 1                                                7.6
# 2                                               11.4
# 3                                               10.2
# 4                                               12.3
#
#    Percent Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                               12.3
# 1                                               28.8
# 2                                               23.6
# 3                                               28.8
# 4                                               31.1
#
#    Percent Population 25 years and over - Some college, no degree  \
# 0                                               18.7
# 1                                               14.5
# 2                                               21.1
# 3                                               21.1
# 4                                               14.3
#
#    Percent Population 25 years and over - Associate's degree  \
# 0                                                7.3
# 1                                                6.0
# 2                                                6.4
# 3                                                7.9
# 4                                                6.3
#
#    Percent Population 25 years and over - Bachelor's degree  \
# 0                                               36.0
# 1                                               22.9
# 2                                               17.4
# 3                                               13.9
# 4                                               10.8
#
#    Percent Population 25 years and over - Graduate or Prefessional Degree  \
# 0                                               18.5
# 1                                               11.9
# 2                                                5.8
# 3                                                7.5
# 4                                                3.2
#
#    Total population  ...  Percent 60 to 64 years  Percent 65 to 74 years  \
# 0           78614.0  ...                     6.4                     8.3
# 1           85572.0  ...                     6.0                     9.0
# 2          350738.0  ...                     4.0                     5.8
# 3          373627.0  ...                     4.5                     6.1
# 4           77056.0  ...                     4.8                     9.0
#
#    Percent 75 to 84 years  Percent 85 years and over  Violent Crimes Sum  \
# 0                     4.6                        2.0               148.0
# 1                     3.8                        2.6               168.0
# 2                     2.9                        1.6              1271.0
# 3                     2.5                        0.9              1810.0
# 4                     2.8                        1.2               299.0
#
#    % All Families  House Price Mean  Crime_Rate_per_100k  \
# 0             5.2          789464.7           188.261633
# 1            11.8          524186.5           196.325901
# 2            11.8          479128.8           362.378756
# 3            14.3          214306.0           484.440364
# 4            14.4          343992.4           388.029485
#
#    Percent Home Occupied  Percent Renter Occupied
# 0              44.102898                55.897102
# 1              41.495811                58.504189
# 2              43.471912                56.528088
# 3              57.775194                42.224806
# 4              54.430721                45.569279
#
# [5 rows x 29 columns]

# %%
y = crime["Crime_Rate_per_100k"]
X = crime.drop(columns=["Crime_Rate_per_100k", "City"])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.25)
X_train.shape
# Out:
# (456, 27)

# %%
 ## Create a Linear Regression Model

# %%
regressor = LinearRegression()
regressor
# Out:
# LinearRegression()

# %%
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"Training Data Score: {regressor.score(X_train, y_train)}")
print(f"Testing Data Score: {regressor.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.6577559391377363
# Testing Data Score: 0.6173210902704784

# %%
predictions = regressor.predict(X_test)
results = pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
results
# Out:
#       Prediction       Actual
# 0     579.437250   427.758519
# 1     412.398522   293.654287
# 2     308.117941   115.905088
# 3     315.608808   299.466012
# 4     119.481950   118.702466
# ..           ...          ...
# 148   636.921264   949.398684
# 149   939.745428  1345.812744
# 150   482.010958   249.867092
# 151  1063.867574  1274.697259
# 152   689.670726   635.655617
#
# [153 rows x 2 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Assume `predictions` are the predicted values for your test set
# and `y_test` are the actual values

mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = mean_squared_error(y_test, predictions, squared=False)
r2 = r2_score(y_test, predictions)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")
# Out:
# Mean Absolute Error (MAE): 104.09251072210834
# Mean Squared Error (MSE): 25007.165759689437
# Root Mean Squared Error (RMSE): 158.1365415066658
# R-squared (R²): 0.6173210902704784
# C:\Users\EJ-PC\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(mae, 2), 'degrees.')

# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test)

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 104.09 degrees.
# Accuracy: 67.22 %.
