# %%
import pandas as pd
import re
from pathlib import Path
df_col_2015=pd.read_csv(Path("header/ACSDP1Y2015.DP03-Column-Metadata.csv"))
df_col_2016=pd.read_csv(Path("header/ACSDP1Y2016.DP03-Column-Metadata.csv")) 
df_col_2017=pd.read_csv(Path("header/ACSDP1Y2017.DP03-Column-Metadata.csv"))
df_col_2018=pd.read_csv(Path("header/ACSDP1Y2018.DP03-Column-Metadata.csv"))
df_col_2019=pd.read_csv(Path("header/ACSDP1Y2019.DP03-Column-Metadata.csv"))
df_col_2015.head()
# Out:
#    Column Name                                              Label
# 0       GEO_ID                                          Geography
# 1         NAME                               Geographic Area Name
# 2   DP03_0001E  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 3   DP03_0001M  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 4  DP03_0001PE  Percent!!EMPLOYMENT STATUS!!Population 16 year...

# %%
for column_name, series in df_col_2015.items():
    print(type(series))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
def extrat_columns_delete(df):
    container=['GEO_ID','NAME']
    container_id=[]
    delete_column=[]
    for index, row in df.iterrows():
        labels=re.search('!!([^!]+)!!',row['Label'])
        if labels:
            found = labels.group(1)
            if found not in container_id:
                container_id.append(found)
                container.append(row['Column Name'])
                print(row['Column Name'],row['Label'])
            else:
                delete_column.append(row['Label'])
    return container

# %%
def cleanCityNames(df):
    df['NAME'] = df['NAME'].str.replace(', California|city|town|CDP', '', regex=True)
    df['NAME']=  df['NAME'].str.strip()
    
def addYear(df,year):
    df.insert(0,'year',year)

# %%
year_2015=extrat_columns_delete(df_col_2015)

year_2016=extrat_columns_delete(df_col_2016)

year_2017=extrat_columns_delete(df_col_2017)

year_2018=extrat_columns_delete(df_col_2018)

year_2019=extrat_columns_delete(df_col_2019)
year_2015
# Out:
# DP03_0001E Estimate!!EMPLOYMENT STATUS!!Population 16 years and over
# DP03_0018E Estimate!!COMMUTING TO WORK!!Workers 16 years and over
# DP03_0026E Estimate!!OCCUPATION!!Civilian employed population 16 years and over
# DP03_0032E Estimate!!INDUSTRY!!Civilian employed population 16 years and over
# DP03_0046E Estimate!!CLASS OF WORKER!!Civilian employed population 16 years and over
# DP03_0051E Estimate!!INCOME AND BENEFITS (IN 2015 INFLATION-ADJUSTED DOLLARS)!!Total households
# DP03_0095E Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population
# DP03_0119E Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families
# DP03_0001E Estimate!!EMPLOYMENT STATUS!!Population 16 years and over
# DP03_0018E Estimate!!COMMUTING TO WORK!!Workers 16 years and over
# DP03_0026E Estimate!!OCCUPATION!!Civilian employed population 16 years and over
# DP03_0032E Estimate!!INDUSTRY!!Civilian employed population 16 years and over
# DP03_0046E Estimate!!CLASS OF WORKER!!Civilian employed population 16 years and over
# DP03_0051E Estimate!!INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS)!!Total households
# DP03_0095E Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population
# DP03_0119E Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families
# DP03_0001E Estimate!!EMPLOYMENT STATUS!!Population 16 years and over
# DP03_0018E Estimate!!COMMUTING TO WORK!!Workers 16 years and over
# DP03_0026E Estimate!!OCCUPATION!!Civilian employed population 16 years and over
# DP03_0032E Estimate!!INDUSTRY!!Civilian employed population 16 years and over
# DP03_0046E Estimate!!CLASS OF WORKER!!Civilian employed population 16 years and over
# DP03_0051E Estimate!!INCOME AND BENEFITS (IN 2017 INFLATION-ADJUSTED DOLLARS)!!Total households
# DP03_0095E Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population
# DP03_0119E Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families
# DP03_0001E Estimate!!EMPLOYMENT STATUS!!Population 16 years and over
# DP03_0018E Estimate!!COMMUTING TO WORK!!Workers 16 years and over
# DP03_0026E Estimate!!OCCUPATION!!Civilian employed population 16 years and over
# DP03_0032E Estimate!!INDUSTRY!!Civilian employed population 16 years and over
# DP03_0046E Estimate!!CLASS OF WORKER!!Civilian employed population 16 years and over
# DP03_0051E Estimate!!INCOME AND BENEFITS (IN 2018 INFLATION-ADJUSTED DOLLARS)!!Total households
# DP03_0095E Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population
# DP03_0119E Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families
# DP03_0001E Estimate!!EMPLOYMENT STATUS!!Population 16 years and over
# DP03_0018E Estimate!!COMMUTING TO WORK!!Workers 16 years and over
# DP03_0026E Estimate!!OCCUPATION!!Civilian employed population 16 years and over
# DP03_0032E Estimate!!INDUSTRY!!Civilian employed population 16 years and over
# DP03_0046E Estimate!!CLASS OF WORKER!!Civilian employed population 16 years and over
# DP03_0051E Estimate!!INCOME AND BENEFITS (IN 2019 INFLATION-ADJUSTED DOLLARS)!!Total households
# DP03_0095E Estimate!!HEALTH INSURANCE COVERAGE!!Civilian noninstitutionalized population
# DP03_0119E Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL!!All families
# ['GEO_ID',
#  'NAME',
#  'DP03_0001E',
#  'DP03_0018E',
#  'DP03_0026E',
#  'DP03_0032E',
#  'DP03_0046E',
#  'DP03_0051E',
#  'DP03_0095E',
#  'DP03_0119E']

# %%
df_data_2015=pd.read_csv('resources/ACSDP1Y2015.DP03-Data.csv')
df_data_2016=pd.read_csv('resources/ACSDP1Y2016.DP03-Data.csv')
df_data_2017=pd.read_csv('resources/ACSDP1Y2017.DP03-Data.csv')
df_data_2018=pd.read_csv('resources/ACSDP1Y2018.DP03-Data.csv')
df_data_2019=pd.read_csv('resources/ACSDP1Y2019.DP03-Data.csv')

df_data_2015.head()
# Out:
#              GEO_ID                       NAME  \
# 0         Geography       Geographic Area Name
# 1  1600000US0600562   Alameda city, California
# 2  1600000US0600884  Alhambra city, California
# 3  1600000US0602000   Anaheim city, California
# 4  1600000US0602252   Antioch city, California
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                              64837
# 2                                              73529
# 3                                             273225
# 4                                              84415
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                               1728
# 2                                               2079
# 3                                               4949
# 4                                               2576
#
#                                          DP03_0001PE  \
# 0  Percent!!EMPLOYMENT STATUS!!Population 16 year...
# 1                                              64837
# 2                                              73529
# 3                                             273225
# 4                                              84415
#
#                                          DP03_0001PM  \
# 0  Percent Margin of Error!!EMPLOYMENT STATUS!!Po...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           DP03_0002E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                              43239
# 2                                              44586
# 3                                             188592
# 4                                              52415
#
#                                           DP03_0002M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                               1638
# 2                                               2302
# 3                                               5413
# 4                                               3267
#
#                                          DP03_0002PE  \
# 0  Percent!!EMPLOYMENT STATUS!!Population 16 year...
# 1                                               66.7
# 2                                               60.6
# 3                                               69.0
# 4                                               62.1
#
#                                          DP03_0002PM  ...  \
# 0  Percent Margin of Error!!EMPLOYMENT STATUS!!Po...  ...
# 1                                                2.7  ...
# 2                                                2.7  ...
# 3                                                1.6  ...
# 4                                                3.7  ...
#
#                                          DP03_0135PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                3.5
# 2                                                6.2
# 3                                                3.5
# 4                                                3.9
#
#                                           DP03_0136E  \
# 0  Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           DP03_0136M  \
# 0  Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                          DP03_0136PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                                5.1
# 2                                               11.4
# 3                                               12.7
# 4                                               10.6
#
#                                          DP03_0136PM  \
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...
# 1                                                2.6
# 2                                                3.6
# 3                                                2.2
# 4                                                4.9
#
#                                           DP03_0137E  \
# 0  Estimate!!PERCENTAGE OF FAMILIES AND PEOPLE WH...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                           DP03_0137M  \
# 0  Margin of Error!!PERCENTAGE OF FAMILIES AND PE...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                          DP03_0137PE  \
# 0  Percent!!PERCENTAGE OF FAMILIES AND PEOPLE WHO...
# 1                                               16.2
# 2                                               38.5
# 3                                               27.6
# 4                                               29.6
#
#                                          DP03_0137PM Unnamed: 550
# 0  Percent Margin of Error!!PERCENTAGE OF FAMILIE...          NaN
# 1                                                5.2          NaN
# 2                                                7.3          NaN
# 3                                                3.6          NaN
# 4                                                8.7          NaN
#
# [5 rows x 551 columns]

# %%
df_data_2015=df_data_2015[year_2015].drop(columns=['DP03_0119E'])
df_data_2016=df_data_2016[year_2016].drop(columns=['DP03_0119E'])
df_data_2017=df_data_2017[year_2017].drop(columns=['DP03_0119E'])
df_data_2018=df_data_2018[year_2018].drop(columns=['DP03_0119E'])
df_data_2019=df_data_2019[year_2019].drop(columns=['DP03_0119E'])

# %%
cleanCityNames(df_data_2015)
cleanCityNames(df_data_2016)
cleanCityNames(df_data_2017)
cleanCityNames(df_data_2018)
cleanCityNames(df_data_2019)

df_data_2015
# Out:
#                GEO_ID                  NAME  \
# 0           Geography  Geographic Area Name
# 1    1600000US0600562               Alameda
# 2    1600000US0600884              Alhambra
# 3    1600000US0602000               Anaheim
# 4    1600000US0602252               Antioch
# ..                ...                   ...
# 133  1600000US0684200           West Covina
# 134  1600000US0684550           Westminster
# 135  1600000US0685292              Whittier
# 136  1600000US0686832           Yorba Linda
# 137  1600000US0686972             Yuba City
#
#                                             DP03_0001E  \
# 0    Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                                64837
# 2                                                73529
# 3                                               273225
# 4                                                84415
# ..                                                 ...
# 133                                              89569
# 134                                              78214
# 135                                              70950
# 136                                              55623
# 137                                              50767
#
#                                             DP03_0018E  \
# 0    Estimate!!COMMUTING TO WORK!!Workers 16 years ...
# 1                                                40671
# 2                                                42187
# 3                                               172376
# 4                                                46827
# ..                                                 ...
# 133                                              52362
# 134                                              44145
# 135                                              42688
# 136                                              32475
# 137                                              24382
#
#                                             DP03_0026E  \
# 0    Estimate!!OCCUPATION!!Civilian employed popula...
# 1                                                40302
# 2                                                42773
# 3                                               175917
# 4                                                48228
# ..                                                 ...
# 133                                              53799
# 134                                              45127
# 135                                              43357
# 136                                              33011
# 137                                              24323
#
#                                             DP03_0032E  \
# 0    Estimate!!INDUSTRY!!Civilian employed populati...
# 1                                                40302
# 2                                                42773
# 3                                               175917
# 4                                                48228
# ..                                                 ...
# 133                                              53799
# 134                                              45127
# 135                                              43357
# 136                                              33011
# 137                                              24323
#
#                                             DP03_0046E  \
# 0    Estimate!!CLASS OF WORKER!!Civilian employed p...
# 1                                                40302
# 2                                                42773
# 3                                               175917
# 4                                                48228
# ..                                                 ...
# 133                                              53799
# 134                                              45127
# 135                                              43357
# 136                                              33011
# 137                                              24323
#
#                                             DP03_0051E  \
# 0    Estimate!!INCOME AND BENEFITS (IN 2015 INFLATI...
# 1                                                30710
# 2                                                29362
# 3                                                99991
# 4                                                33214
# ..                                                 ...
# 133                                              30233
# 134                                              28002
# 135                                              27548
# 136                                              22559
# 137                                              22787
#
#                                             DP03_0095E
# 0    Estimate!!HEALTH INSURANCE COVERAGE!!Civilian ...
# 1                                                76782
# 2                                                84959
# 3                                               348424
# 4                                               110183
# ..                                                 ...
# 133                                             107975
# 134                                              91926
# 135                                              86950
# 136                                              67895
# 137                                              65496
#
# [138 rows x 9 columns]

# %%
addYear(df_data_2015, '2015')
addYear(df_data_2016, '2016')
addYear(df_data_2017, '2017')
addYear(df_data_2018, '2018')
addYear(df_data_2019, '2019')

# %%
df_data_2015.head()
# Out:
#    year            GEO_ID                  NAME  \
# 0  2015         Geography  Geographic Area Name
# 1  2015  1600000US0600562               Alameda
# 2  2015  1600000US0600884              Alhambra
# 3  2015  1600000US0602000               Anaheim
# 4  2015  1600000US0602252               Antioch
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                              64837
# 2                                              73529
# 3                                             273225
# 4                                              84415
#
#                                           DP03_0018E  \
# 0  Estimate!!COMMUTING TO WORK!!Workers 16 years ...
# 1                                              40671
# 2                                              42187
# 3                                             172376
# 4                                              46827
#
#                                           DP03_0026E  \
# 0  Estimate!!OCCUPATION!!Civilian employed popula...
# 1                                              40302
# 2                                              42773
# 3                                             175917
# 4                                              48228
#
#                                           DP03_0032E  \
# 0  Estimate!!INDUSTRY!!Civilian employed populati...
# 1                                              40302
# 2                                              42773
# 3                                             175917
# 4                                              48228
#
#                                           DP03_0046E  \
# 0  Estimate!!CLASS OF WORKER!!Civilian employed p...
# 1                                              40302
# 2                                              42773
# 3                                             175917
# 4                                              48228
#
#                                           DP03_0051E  \
# 0  Estimate!!INCOME AND BENEFITS (IN 2015 INFLATI...
# 1                                              30710
# 2                                              29362
# 3                                              99991
# 4                                              33214
#
#                                           DP03_0095E
# 0  Estimate!!HEALTH INSURANCE COVERAGE!!Civilian ...
# 1                                              76782
# 2                                              84959
# 3                                             348424
# 4                                             110183

# %%
df_data_2016.head()
# Out:
#    year            GEO_ID                  NAME  \
# 0  2016         Geography  Geographic Area Name
# 1  2016  1600000US0600562               Alameda
# 2  2016  1600000US0600884              Alhambra
# 3  2016  1600000US0602000               Anaheim
# 4  2016  1600000US0602252               Antioch
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                              63244
# 2                                              71757
# 3                                             273702
# 4                                              86394
#
#                                           DP03_0018E  \
# 0  Estimate!!COMMUTING TO WORK!!Workers 16 years ...
# 1                                              40339
# 2                                              40747
# 3                                             165208
# 4                                              49642
#
#                                           DP03_0026E  \
# 0  Estimate!!OCCUPATION!!Civilian employed popula...
# 1                                              39901
# 2                                              41570
# 3                                             168898
# 4                                              51405
#
#                                           DP03_0032E  \
# 0  Estimate!!INDUSTRY!!Civilian employed populati...
# 1                                              39901
# 2                                              41570
# 3                                             168898
# 4                                              51405
#
#                                           DP03_0046E  \
# 0  Estimate!!CLASS OF WORKER!!Civilian employed p...
# 1                                              39901
# 2                                              41570
# 3                                             168898
# 4                                              51405
#
#                                           DP03_0051E  \
# 0  Estimate!!INCOME AND BENEFITS (IN 2016 INFLATI...
# 1                                              30338
# 2                                              27960
# 3                                              99255
# 4                                              34163
#
#                                           DP03_0095E
# 0  Estimate!!HEALTH INSURANCE COVERAGE!!Civilian ...
# 1                                              77189
# 2                                              84886
# 3                                             349332
# 4                                             110589

# %%
df_data_2017.head()
# Out:
#    year            GEO_ID                  NAME  \
# 0  2017         Geography  Geographic Area Name
# 1  2017  1600000US0600562               Alameda
# 2  2017  1600000US0600884              Alhambra
# 3  2017  1600000US0602000               Anaheim
# 4  2017  1600000US0602252               Antioch
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                              62878
# 2                                              74492
# 3                                             277723
# 4                                              86577
#
#                                           DP03_0018E  \
# 0  Estimate!!COMMUTING TO WORK!!Workers 16 years ...
# 1                                              40494
# 2                                              42137
# 3                                             172265
# 4                                              49212
#
#                                           DP03_0026E  \
# 0  Estimate!!OCCUPATION!!Civilian employed popula...
# 1                                              40517
# 2                                              42983
# 3                                             176061
# 4                                              50870
#
#                                           DP03_0032E  \
# 0  Estimate!!INDUSTRY!!Civilian employed populati...
# 1                                              40517
# 2                                              42983
# 3                                             176061
# 4                                              50870
#
#                                           DP03_0046E  \
# 0  Estimate!!CLASS OF WORKER!!Civilian employed p...
# 1                                              40517
# 2                                              42983
# 3                                             176061
# 4                                              50870
#
#                                           DP03_0051E  \
# 0  Estimate!!INCOME AND BENEFITS (IN 2017 INFLATI...
# 1                                              30662
# 2                                              30255
# 3                                              98734
# 4                                              34423
#
#                                           DP03_0095E
# 0  Estimate!!HEALTH INSURANCE COVERAGE!!Civilian ...
# 1                                              77864
# 2                                              84704
# 3                                             350585
# 4                                             111346

# %%
df_data_2018.head()
# Out:
#    year            GEO_ID                  NAME  \
# 0  2018         Geography  Geographic Area Name
# 1  2018  1600000US0600562               Alameda
# 2  2018  1600000US0600884              Alhambra
# 3  2018  1600000US0602000               Anaheim
# 4  2018  1600000US0602252               Antioch
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                              63939
# 2                                              72616
# 3                                             273400
# 4                                              86434
#
#                                           DP03_0018E  \
# 0  Estimate!!COMMUTING TO WORK!!Workers 16 years ...
# 1                                              42117
# 2                                              42933
# 3                                             177118
# 4                                              48634
#
#                                           DP03_0026E  \
# 0  Estimate!!OCCUPATION!!Civilian employed popula...
# 1                                              42646
# 2                                              43887
# 3                                             180144
# 4                                              50684
#
#                                           DP03_0032E  \
# 0  Estimate!!INDUSTRY!!Civilian employed populati...
# 1                                              42646
# 2                                              43887
# 3                                             180144
# 4                                              50684
#
#                                           DP03_0046E  \
# 0  Estimate!!CLASS OF WORKER!!Civilian employed p...
# 1                                              42646
# 2                                              43887
# 3                                             180144
# 4                                              50684
#
#                                           DP03_0051E  \
# 0  Estimate!!INCOME AND BENEFITS (IN 2018 INFLATI...
# 1                                              30724
# 2                                              30556
# 3                                             101547
# 4                                              34518
#
#                                           DP03_0095E
# 0  Estimate!!HEALTH INSURANCE COVERAGE!!Civilian ...
# 1                                              77221
# 2                                              84081
# 3                                             350225
# 4                                             111167

# %%
df_data_2019.head()
# Out:
#    year            GEO_ID                  NAME  \
# 0  2019         Geography  Geographic Area Name
# 1  2019  1600000US0600562               Alameda
# 2  2019  1600000US0600884              Alhambra
# 3  2019  1600000US0602000               Anaheim
# 4  2019  1600000US0602252               Antioch
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                              63509
# 2                                              70780
# 3                                             281221
# 4                                              90801
#
#                                           DP03_0018E  \
# 0  Estimate!!COMMUTING TO WORK!!Workers 16 years ...
# 1                                              40595
# 2                                              43631
# 3                                             183442
# 4                                              51280
#
#                                           DP03_0026E  \
# 0  Estimate!!OCCUPATION!!Civilian employed popula...
# 1                                              40937
# 2                                              44496
# 3                                             186332
# 4                                              52096
#
#                                           DP03_0032E  \
# 0  Estimate!!INDUSTRY!!Civilian employed populati...
# 1                                              40937
# 2                                              44496
# 3                                             186332
# 4                                              52096
#
#                                           DP03_0046E  \
# 0  Estimate!!CLASS OF WORKER!!Civilian employed p...
# 1                                              40937
# 2                                              44496
# 3                                             186332
# 4                                              52096
#
#                                           DP03_0051E  \
# 0  Estimate!!INCOME AND BENEFITS (IN 2019 INFLATI...
# 1                                              30788
# 2                                              28777
# 3                                             105301
# 4                                              36138
#
#                                           DP03_0095E
# 0  Estimate!!HEALTH INSURANCE COVERAGE!!Civilian ...
# 1                                              76349
# 2                                              83113
# 3                                             348028
# 4                                             111230

# %%
df_data_2015.to_csv('clean_data/incomes_2015.csv',index=False)
df_data_2016.to_csv('clean_data/incomes_2016.csv',index=False)
df_data_2017.to_csv('clean_data/incomes_2017.csv',index=False)
df_data_2018.to_csv('clean_data/incomes_2018.csv',index=False)
df_data_2019.to_csv('clean_data/incomes_2019.csv',index=False)

# %%
df_data_2015to2019 = pd.concat([df_data_2015, df_data_2016.iloc[1:],df_data_2017.iloc[1:],df_data_2018.iloc[1:],df_data_2019.iloc[1:]])
df_data_2015to2019.to_csv('clean_data/incomes_2015to2019.csv',index=False)
