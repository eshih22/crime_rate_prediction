# %%
import pandas as pd
import re
from pathlib import Path

# %%
edu_data=pd.read_csv(Path("education_level_california/clean_education_level.csv"))
edu_data = edu_data.rename(columns={'Geographic Area Name': 'City'})
edu_data.head()
# Out:
#    Year          City  Population 25 years and over - Less than 9th grade  \
# 0  2015       Alameda                                               2089
# 1  2015      Alhambra                                               5402
# 2  2015       Anaheim                                              32506
# 3  2015       Antioch                                               5393
# 4  2015  Apple Valley                                               1502
#
#    Percent Population 25 years and over - Less than 9th grade  \
# 0                                                3.6
# 1                                                8.3
# 2                                               14.4
# 3                                                7.8
# 4                                                3.5
#
#    Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                               2089
# 1                                               4923
# 2                                              25762
# 3                                               3315
# 4                                               4536
#
#    Percent Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                3.6
# 1                                                7.6
# 2                                               11.4
# 3                                                4.8
# 4                                               10.5
#
#    Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                               7242
# 1                                              18760
# 2                                              53477
# 3                                              17637
# 4                                              14301
#
#    Percent Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                               12.3
# 1                                               28.8
# 2                                               23.6
# 3                                               25.7
# 4                                               33.1
#
#    Population 25 years and over - Some college, no degree  \
# 0                                              11010
# 1                                               9435
# 2                                              47633
# 3                                              23049
# 4                                              11302
#
#    Percent Population 25 years and over - Some college, no degree  \
# 0                                               18.7
# 1                                               14.5
# 2                                               21.1
# 3                                               33.5
# 4                                               26.2
#
#    Population 25 years and over - Associate's degree  \
# 0                                               4306
# 1                                               3932
# 2                                              14397
# 3                                               5950
# 4                                               3354
#
#    Percent Population 25 years and over - Associate's degree  \
# 0                                                7.3
# 1                                                6.0
# 2                                                6.4
# 3                                                8.7
# 4                                                7.8
#
#    Population 25 years and over - Bachelor's degree  \
# 0                                             21182
# 1                                             14871
# 2                                             39422
# 3                                              9369
# 4                                              4941
#
#    Percent Population 25 years and over - Bachelor's degree  \
# 0                                               36.0
# 1                                               22.9
# 2                                               17.4
# 3                                               13.6
# 4                                               11.4
#
#    Population 25 years and over - Graduate or Prefessional Degree  \
# 0                                              10862
# 1                                               7725
# 2                                              13082
# 3                                               4041
# 4                                               3219
#
#    Percent Population 25 years and over - Graduate or Prefessional Degree
# 0                                               18.5
# 1                                               11.9
# 2                                                5.8
# 3                                                5.9
# 4                                                7.5

# %%
age_data=pd.read_csv(Path("Age_Data/Merged_Age.csv"))

age_data.head()
# Out:
#    Year          City Total population Under 5 years Percent Under 5 years  \
# 0  2015       Alameda           78,614         4,187                 5.30%
# 1  2015      Alhambra           85,572         3,829                 4.50%
# 2  2015       Anaheim          350,738        24,928                 7.10%
# 3  2015        Antioc          110,542         8,080                 7.30%
# 4  2015  Apple Valley           72,185         5,389                 7.50%
#
#   5 to 9 years Percent 5 to 9 years 10 to 14 years Percent 10 to 14 years  \
# 0        4,856                6.20%          4,035                  5.10%
# 1        3,999                4.70%          3,335                  3.90%
# 2       24,294                6.90%         22,470                  6.40%
# 3        7,804                7.10%          8,237                  7.50%
# 4        6,005                8.30%          5,505                  7.60%
#
#   15 to 19 years  ... 55 to 59 years Percent 55 to 59 years 60 to 64 years  \
# 0          2,754  ...          5,773                  7.30%          5,014
# 1          3,942  ...          7,603                  8.90%          5,149
# 2         24,202  ...         18,960                  5.40%         14,055
# 3          8,101  ...          8,494                  7.70%          5,184
# 4          6,401  ...          3,837                  5.30%          4,452
#
#   Percent 60 to 64 years 65 to 74 years Percent 65 to 74 years 75 to 84 years  \
# 0                  6.40%          6,529                  8.30%          3,599
# 1                  6.00%          7,685                  9.00%          3,237
# 2                  4.00%         20,364                  5.80%         10,167
# 3                  4.70%          6,757                  6.10%          2,649
# 4                  6.20%          6,897                  9.60%          4,422
#
#   Percent 75 to 84 years 85 years and over Percent 85 years and over
# 0                  4.60%             1,541                     2.00%
# 1                  3.80%             2,210                     2.60%
# 2                  2.90%             5,608                     1.60%
# 3                  2.40%             1,485                     1.30%
# 4                  6.10%             1,044                     1.40%
#
# [5 rows x 29 columns]

# %%
crime_data=pd.read_csv(Path("crime_data/crime_cleaned.csv"))

crime_data.head()
# Out:
#    Year                              City  Violent Crimes Sum
# 0  2015  Alameda Co. Sheriff's Department                 510
# 1  2015                           Alameda                 148
# 2  2015                            Albany                  34
# 3  2015                          Berkeley                 530
# 4  2015                        Emeryville                 153

# %%
income_data=pd.read_csv(Path("data_incomes_california_cities/clean_data/incomes_2015to2019.csv"))

income_data.head()
# Out:
#    Year          City  Unemployment Rate  Income
# 0  2015       Alameda                4.3   30710
# 1  2015      Alhambra                4.1   29362
# 2  2015       Anaheim                6.7   99991
# 3  2015       Antioch                7.8   33214
# 4  2015  Apple Valley               11.5   23644

# %%
income_data=pd.read_csv(Path("Poverty_Resources/All_Family_Poverty.csv"))

income_data.head()
# Out:
#    Year          City % All Families
# 0  2015       Alameda            5.2
# 1  2015      Alhambra           11.8
# 2  2015       Anaheim           11.8
# 3  2015       Antioch           11.8
# 4  2015  Apple Valley           19.3

# %%
house_price_data=pd.read_csv(Path("Poverty_Resources/Clean_House_Price.csv"))
house_price_data = house_price_data.rename(columns={'RegionName': 'City'})
house_price_data.head()
# Out:
#    Year          City House Price Mean
# 0  2015        Acampo         405627.8
# 1  2015         Acton         432973.8
# 2  2015      Adelanto         151341.3
# 3  2015          Adin         153454.8
# 4  2015  Agoura Hills         695740.1

# %%
rent_own_data=pd.read_csv(Path("rent_vs_own_data/rent_vs_own_cleaned.csv"))

rent_own_data.head()
# Out:
#    Year               City   Total Total Occupied Renter occupied
# 0  2015            Alameda  30,710         13,544          17,166
# 1  2015           Alhambra  29,362         12,184          17,178
# 2  2015            Anaheim  99,991         43,468          56,523
# 3  2015            Antioch  33,214         18,808          14,406
# 4  2015  Apple Valley town  23,644         15,407           8,237

# %%
# edu_data age_data crime_data income_data house_price_data rent_own_data
all_df = edu_data.merge(age_data, on=['City', 'Year'], how='left') \
                 .merge(crime_data, on=['City', 'Year'], how='left') \
                 .merge(income_data, on=['City', 'Year'], how='left') \
                 .merge(house_price_data, on=['City', 'Year'], how='left') \
                 .merge(rent_own_data, on=['City', 'Year'], how='left')

# %%
all_df
# Out:
#      Year          City  Population 25 years and over - Less than 9th grade  \
# 0    2015       Alameda                                               2089
# 1    2015      Alhambra                                               5402
# 2    2015       Anaheim                                              32506
# 3    2015       Antioch                                               5393
# 4    2015  Apple Valley                                               1502
# ..    ...           ...                                                ...
# 699  2019   West Covina                                               5308
# 700  2019   Westminster                                               8307
# 701  2019      Whittier                                               3021
# 702  2019   Yorba Linda                                                613
# 703  2019     Yuba City                                               5344
#
#      Percent Population 25 years and over - Less than 9th grade  \
# 0                                                 3.60
# 1                                                 8.30
# 2                                                14.40
# 3                                                 7.80
# 4                                                 3.50
# ..                                                 ...
# 699                                               7.09
# 700                                              13.03
# 701                                               5.44
# 702                                               1.24
# 703                                              11.93
#
#      Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                 2089
# 1                                                 4923
# 2                                                25762
# 3                                                 3315
# 4                                                 4536
# ..                                                 ...
# 699                                               4530
# 700                                               6607
# 701                                               3921
# 702                                               1576
# 703                                               4756
#
#      Percent Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                 3.60
# 1                                                 7.60
# 2                                                11.40
# 3                                                 4.80
# 4                                                10.50
# ..                                                 ...
# 699                                               6.05
# 700                                              10.36
# 701                                               7.06
# 702                                               3.19
# 703                                              10.62
#
#      Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                                 7242
# 1                                                18760
# 2                                                53477
# 3                                                17637
# 4                                                14301
# ..                                                 ...
# 699                                              20919
# 700                                              15641
# 701                                              16232
# 702                                               6748
# 703                                               9396
#
#      Percent Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                                12.30
# 1                                                28.80
# 2                                                23.60
# 3                                                25.70
# 4                                                33.10
# ..                                                 ...
# 699                                              27.95
# 700                                              24.53
# 701                                              29.24
# 702                                              13.65
# 703                                              20.97
#
#      Population 25 years and over - Some college, no degree  \
# 0                                                11010
# 1                                                 9435
# 2                                                47633
# 3                                                23049
# 4                                                11302
# ..                                                 ...
# 699                                              16083
# 700                                              11273
# 701                                              12079
# 702                                               9289
# 703                                              11112
#
#      Percent Population 25 years and over - Some college, no degree  ...  \
# 0                                                18.70               ...
# 1                                                14.50               ...
# 2                                                21.10               ...
# 3                                                33.50               ...
# 4                                                26.20               ...
# ..                                                 ...               ...
# 699                                              21.49               ...
# 700                                              17.68               ...
# 701                                              21.76               ...
# 702                                              18.79               ...
# 703                                              24.80               ...
#
#      75 to 84 years  Percent 75 to 84 years  85 years and over  \
# 0             3,599                   4.60%              1,541
# 1             3,237                   3.80%              2,210
# 2            10,167                   2.90%              5,608
# 3               NaN                     NaN                NaN
# 4             4,422                   6.10%              1,044
# ..              ...                     ...                ...
# 699           5,011                   4.80%              1,728
# 700           5,885                   6.50%              2,319
# 701           4,251                   5.00%              1,658
# 702           4,071                   6.00%                884
# 703           3,803                   5.70%              1,502
#
#      Percent 85 years and over  Violent Crimes Sum  % All Families  \
# 0                        2.00%               148.0             5.2
# 1                        2.60%               168.0            11.8
# 2                        1.60%              1271.0            11.8
# 3                          NaN               771.0            11.8
# 4                        1.40%               234.0            19.3
# ..                         ...                 ...             ...
# 699                      1.60%               260.0             4.1
# 700                      2.60%               259.0            13.5
# 701                      1.90%               213.0             4.7
# 702                      1.30%                42.0             3.5
# 703                      2.20%               241.0            11.3
#
#     House Price Mean   Total Total Occupied Renter occupied
# 0           789464.7  30,710         13,544          17,166
# 1           524186.5  29,362         12,184          17,178
# 2           479128.8  99,991         43,468          56,523
# 3           323531.8  33,214         18,808          14,406
# 4           194588.4     NaN            NaN             NaN
# ..               ...     ...            ...             ...
# 699         570472.8  30,682         17,788          12,894
# 700         676782.2  26,984         12,741          14,243
# 701         552625.8  26,884         16,380          10,504
# 702         846823.6     NaN            NaN             NaN
# 703         307497.6  24,393         13,304          11,089
#
# [704 rows x 49 columns]

# %%
all_df_clean = all_df.dropna()

# %%
all_df_reset = all_df_clean.reset_index(drop=True)

# %%
all_df_reset.dtypes
# Out:
# Year                                                                              int64
# City                                                                             object
# Population 25 years and over - Less than 9th grade                                int64
# Percent Population 25 years and over - Less than 9th grade                      float64
# Population 25 years and over - 9th to12th (No Diploma)                            int64
# Percent Population 25 years and over - 9th to12th (No Diploma)                  float64
# Population 25 years and over - High School Graduate (and equivalent)              int64
# Percent Population 25 years and over - High School Graduate (and equivalent)    float64
# Population 25 years and over - Some college, no degree                            int64
# Percent Population 25 years and over - Some college, no degree                  float64
# Population 25 years and over - Associate's degree                                 int64
# Percent Population 25 years and over - Associate's degree                       float64
# Population 25 years and over - Bachelor's degree                                  int64
# Percent Population 25 years and over - Bachelor's degree                        float64
# Population 25 years and over - Graduate or Prefessional Degree                    int64
# Percent Population 25 years and over - Graduate or Prefessional Degree          float64
# Total population                                                                 object
# Under 5 years                                                                    object
# Percent Under 5 years                                                            object
# 5 to 9 years                                                                     object
# Percent 5 to 9 years                                                             object
# 10 to 14 years                                                                   object
# Percent 10 to 14 years                                                           object
# 15 to 19 years                                                                   object
# Percent 15 to 19 years                                                           object
# 20 to 24 years                                                                   object
# Percent 20 to 24 years                                                           object
# 25 to 34 years                                                                   object
# Percent 25 to 34 years                                                           object
# 35 to 44 years                                                                   object
# Percent 35 to 44 years                                                           object
# 45 to 54 years                                                                   object
# Percent 45 to 54 years                                                           object
# 55 to 59 years                                                                   object
# Percent 55 to 59 years                                                           object
# 60 to 64 years                                                                   object
# Percent 60 to 64 years                                                           object
# 65 to 74 years                                                                   object
# Percent 65 to 74 years                                                           object
# 75 to 84 years                                                                   object
# Percent 75 to 84 years                                                           object
# 85 years and over                                                                object
# Percent 85 years and over                                                        object
# Violent Crimes Sum                                                              float64
# % All Families                                                                   object
# House Price Mean                                                                 object
# Total                                                                            object
# Total Occupied                                                                   object
# Renter occupied                                                                  object
# dtype: object

# %%
columns_to_drop = ['Population 25 years and over - Less than 9th grade',
                   'Population 25 years and over - 9th to12th (No Diploma)',
                   'Population 25 years and over - High School Graduate (and equivalent)',
                   'Population 25 years and over - Some college, no degree',
                   "Population 25 years and over - Associate's degree",
                   "Population 25 years and over - Bachelor's degree",
                   "Population 25 years and over - Graduate or Prefessional Degree",
                   "Under 5 years",
                   "5 to 9 years",
                   "10 to 14 years",
                   "15 to 19 years",
                   "20 to 24 years",
                   "25 to 34 years",
                   "35 to 44 years",
                   "45 to 54 years",
                   "55 to 59 years", 
                   "60 to 64 years",
                   "65 to 74 years",
                   "75 to 84 years",
                   "85 years and over",
                   "Total Occupied",
                   "Renter occupied",
                   "Total",
                   
                  ]

# %%
columns_to_convert = [
    'Total population', 'Under 5 years', 'Percent Under 5 years', 
    '5 to 9 years', 'Percent 5 to 9 years', '10 to 14 years', 
    'Percent 10 to 14 years', '15 to 19 years', 'Percent 15 to 19 years', 
    '20 to 24 years', 'Percent 20 to 24 years', '25 to 34 years', 
    'Percent 25 to 34 years', '35 to 44 years', 'Percent 35 to 44 years', 
    '45 to 54 years', 'Percent 45 to 54 years', '55 to 59 years', 
    'Percent 55 to 59 years', '60 to 64 years', 'Percent 60 to 64 years', 
    '65 to 74 years', 'Percent 65 to 74 years', '75 to 84 years', 
    'Percent 75 to 84 years', '85 years and over', 'Percent 85 years and over', 'Total', 'Total Occupied', 'Renter occupied'
]

for column in columns_to_convert:
    all_df_reset[column] = all_df_reset[column].str.replace(',|%', '', regex=True) .astype(float)

# %%
all_df_reset['Crime_Rate_per_100k'] = (all_df_reset['Violent Crimes Sum'] / all_df_reset['Total population']) * 100000
all_df_reset['Percent Home Occupied'] = all_df_reset['Total Occupied'] / all_df_reset['Total'] * 100
all_df_reset['Percent Renter Occupied'] = all_df_reset['Renter occupied'] / all_df_reset['Total'] * 100

# %%
all_df_reset
# Out:
#      Year          City  Population 25 years and over - Less than 9th grade  \
# 0    2015       Alameda                                               2089
# 1    2015      Alhambra                                               5402
# 2    2015       Anaheim                                              32506
# 3    2015   Bakersfield                                              23326
# 4    2015  Baldwin Park                                              11082
# ..    ...           ...                                                ...
# 604  2019         Vista                                              10080
# 605  2019   West Covina                                               5308
# 606  2019   Westminster                                               8307
# 607  2019      Whittier                                               3021
# 608  2019     Yuba City                                               5344
#
#      Percent Population 25 years and over - Less than 9th grade  \
# 0                                                 3.60
# 1                                                 8.30
# 2                                                14.40
# 3                                                10.60
# 4                                                22.10
# ..                                                 ...
# 604                                              15.05
# 605                                               7.09
# 606                                              13.03
# 607                                               5.44
# 608                                              11.93
#
#      Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                 2089
# 1                                                 4923
# 2                                                25762
# 3                                                22434
# 4                                                 6156
# ..                                                 ...
# 604                                               6638
# 605                                               4530
# 606                                               6607
# 607                                               3921
# 608                                               4756
#
#      Percent Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                 3.60
# 1                                                 7.60
# 2                                                11.40
# 3                                                10.20
# 4                                                12.30
# ..                                                 ...
# 604                                               9.91
# 605                                               6.05
# 606                                              10.36
# 607                                               7.06
# 608                                              10.62
#
#      Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                                 7242
# 1                                                18760
# 2                                                53477
# 3                                                63568
# 4                                                15636
# ..                                                 ...
# 604                                              13245
# 605                                              20919
# 606                                              15641
# 607                                              16232
# 608                                               9396
#
#      Percent Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                                12.30
# 1                                                28.80
# 2                                                23.60
# 3                                                28.80
# 4                                                31.10
# ..                                                 ...
# 604                                              19.77
# 605                                              27.95
# 606                                              24.53
# 607                                              29.24
# 608                                              20.97
#
#      Population 25 years and over - Some college, no degree  \
# 0                                                11010
# 1                                                 9435
# 2                                                47633
# 3                                                46592
# 4                                                 7172
# ..                                                 ...
# 604                                              16027
# 605                                              16083
# 606                                              11273
# 607                                              12079
# 608                                              11112
#
#      Percent Population 25 years and over - Some college, no degree  ...  \
# 0                                                18.70               ...
# 1                                                14.50               ...
# 2                                                21.10               ...
# 3                                                21.10               ...
# 4                                                14.30               ...
# ..                                                 ...               ...
# 604                                              23.93               ...
# 605                                              21.49               ...
# 606                                              17.68               ...
# 607                                              21.76               ...
# 608                                              24.80               ...
#
#      Percent 85 years and over  Violent Crimes Sum  % All Families  \
# 0                          2.0               148.0             5.2
# 1                          2.6               168.0            11.8
# 2                          1.6              1271.0            11.8
# 3                          0.9              1810.0            14.3
# 4                          1.2               299.0            14.4
# ..                         ...                 ...             ...
# 604                        1.5               354.0             7.9
# 605                        1.6               260.0             4.1
# 606                        2.6               259.0            13.5
# 607                        1.9               213.0             4.7
# 608                        2.2               241.0            11.3
#
#      House Price Mean     Total  Total Occupied  Renter occupied  \
# 0            789464.7   30710.0         13544.0          17166.0
# 1            524186.5   29362.0         12184.0          17178.0
# 2            479128.8   99991.0         43468.0          56523.0
# 3              214306  114383.0         66085.0          48298.0
# 4            343992.4   18541.0         10092.0           8449.0
# ..                ...       ...             ...              ...
# 604          544957.1   31075.0         14209.0          16866.0
# 605          570472.8   30682.0         17788.0          12894.0
# 606          676782.2   26984.0         12741.0          14243.0
# 607          552625.8   26884.0         16380.0          10504.0
# 608          307497.6   24393.0         13304.0          11089.0
#
#      Crime_Rate_per_100k  Percent Home Occupied  Percent Renter Occupied
# 0             188.261633              44.102898                55.897102
# 1             196.325901              41.495811                58.504189
# 2             362.378756              43.471912                56.528088
# 3             484.440364              57.775194                42.224806
# 4             388.029485              54.430721                45.569279
# ..                   ...                    ...                      ...
# 604           348.291502              45.724859                54.275141
# 605           247.350496              57.975360                42.024640
# 606           285.739503              47.216869                52.783131
# 607           250.332013              60.928433                39.071567
# 608           359.653181              54.540237                45.459763
#
# [609 rows x 52 columns]

# %%
all_df_reset = all_df_reset.drop(columns=columns_to_drop, errors='ignore')

# %%
all_df_reset.dtypes
# Out:
# Year                                                                              int64
# City                                                                             object
# Percent Population 25 years and over - Less than 9th grade                      float64
# Percent Population 25 years and over - 9th to12th (No Diploma)                  float64
# Percent Population 25 years and over - High School Graduate (and equivalent)    float64
# Percent Population 25 years and over - Some college, no degree                  float64
# Percent Population 25 years and over - Associate's degree                       float64
# Percent Population 25 years and over - Bachelor's degree                        float64
# Percent Population 25 years and over - Graduate or Prefessional Degree          float64
# Total population                                                                float64
# Percent Under 5 years                                                           float64
# Percent 5 to 9 years                                                            float64
# Percent 10 to 14 years                                                          float64
# Percent 15 to 19 years                                                          float64
# Percent 20 to 24 years                                                          float64
# Percent 25 to 34 years                                                          float64
# Percent 35 to 44 years                                                          float64
# Percent 45 to 54 years                                                          float64
# Percent 55 to 59 years                                                          float64
# Percent 60 to 64 years                                                          float64
# Percent 65 to 74 years                                                          float64
# Percent 75 to 84 years                                                          float64
# Percent 85 years and over                                                       float64
# Violent Crimes Sum                                                              float64
# % All Families                                                                   object
# House Price Mean                                                                 object
# Crime_Rate_per_100k                                                             float64
# Percent Home Occupied                                                           float64
# Percent Renter Occupied                                                         float64
# dtype: object

# %%
# List of columns to convert from 'object' to 'float64'
percentage_columns = [
    'Percent Under 5 years',
    'Percent 5 to 9 years',
    'Percent 10 to 14 years',
    'Percent 15 to 19 years',
    'Percent 20 to 24 years',
    'Percent 25 to 34 years',
    'Percent 35 to 44 years',
    'Percent 45 to 54 years',
    'Percent 55 to 59 years',
    'Percent 60 to 64 years',
    'Percent 65 to 74 years',
    'Percent 75 to 84 years',
    'Percent 85 years and over',
    '% All Families',
    'House Price Mean',
    'Total population'
]

# Convert each of the percentage columns to numeric type (float64)
for column in percentage_columns:
    all_df_reset[column] = pd.to_numeric(all_df_reset[column], errors='coerce')

# Check the data types again to confirm the changes
print(all_df_reset.dtypes)
# Out:
# Year                                                                              int64
# City                                                                             object
# Percent Population 25 years and over - Less than 9th grade                      float64
# Percent Population 25 years and over - 9th to12th (No Diploma)                  float64
# Percent Population 25 years and over - High School Graduate (and equivalent)    float64
# Percent Population 25 years and over - Some college, no degree                  float64
# Percent Population 25 years and over - Associate's degree                       float64
# Percent Population 25 years and over - Bachelor's degree                        float64
# Percent Population 25 years and over - Graduate or Prefessional Degree          float64
# Total population                                                                float64
# Percent Under 5 years                                                           float64
# Percent 5 to 9 years                                                            float64
# Percent 10 to 14 years                                                          float64
# Percent 15 to 19 years                                                          float64
# Percent 20 to 24 years                                                          float64
# Percent 25 to 34 years                                                          float64
# Percent 35 to 44 years                                                          float64
# Percent 45 to 54 years                                                          float64
# Percent 55 to 59 years                                                          float64
# Percent 60 to 64 years                                                          float64
# Percent 65 to 74 years                                                          float64
# Percent 75 to 84 years                                                          float64
# Percent 85 years and over                                                       float64
# Violent Crimes Sum                                                              float64
# % All Families                                                                  float64
# House Price Mean                                                                float64
# Crime_Rate_per_100k                                                             float64
# Percent Home Occupied                                                           float64
# Percent Renter Occupied                                                         float64
# dtype: object

# %%
all_df_reset
# Out:
#      Year          City  \
# 0    2015       Alameda
# 1    2015      Alhambra
# 2    2015       Anaheim
# 3    2015   Bakersfield
# 4    2015  Baldwin Park
# ..    ...           ...
# 604  2019         Vista
# 605  2019   West Covina
# 606  2019   Westminster
# 607  2019      Whittier
# 608  2019     Yuba City
#
#      Percent Population 25 years and over - Less than 9th grade  \
# 0                                                 3.60
# 1                                                 8.30
# 2                                                14.40
# 3                                                10.60
# 4                                                22.10
# ..                                                 ...
# 604                                              15.05
# 605                                               7.09
# 606                                              13.03
# 607                                               5.44
# 608                                              11.93
#
#      Percent Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                 3.60
# 1                                                 7.60
# 2                                                11.40
# 3                                                10.20
# 4                                                12.30
# ..                                                 ...
# 604                                               9.91
# 605                                               6.05
# 606                                              10.36
# 607                                               7.06
# 608                                              10.62
#
#      Percent Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                                12.30
# 1                                                28.80
# 2                                                23.60
# 3                                                28.80
# 4                                                31.10
# ..                                                 ...
# 604                                              19.77
# 605                                              27.95
# 606                                              24.53
# 607                                              29.24
# 608                                              20.97
#
#      Percent Population 25 years and over - Some college, no degree  \
# 0                                                18.70
# 1                                                14.50
# 2                                                21.10
# 3                                                21.10
# 4                                                14.30
# ..                                                 ...
# 604                                              23.93
# 605                                              21.49
# 606                                              17.68
# 607                                              21.76
# 608                                              24.80
#
#      Percent Population 25 years and over - Associate's degree  \
# 0                                                 7.30
# 1                                                 6.00
# 2                                                 6.40
# 3                                                 7.90
# 4                                                 6.30
# ..                                                 ...
# 604                                               8.98
# 605                                               9.00
# 606                                               7.78
# 607                                               9.68
# 608                                               9.17
#
#      Percent Population 25 years and over - Bachelor's degree  \
# 0                                                36.00
# 1                                                22.90
# 2                                                17.40
# 3                                                13.90
# 4                                                10.80
# ..                                                 ...
# 604                                              15.94
# 605                                              20.79
# 606                                              19.52
# 607                                              15.42
# 608                                              12.69
#
#      Percent Population 25 years and over - Graduate or Prefessional Degree  \
# 0                                                18.50
# 1                                                11.90
# 2                                                 5.80
# 3                                                 7.50
# 4                                                 3.20
# ..                                                 ...
# 604                                               6.42
# 605                                               7.62
# 606                                               7.11
# 607                                              11.39
# 608                                               9.83
#
#      Total population  ...  Percent 60 to 64 years  Percent 65 to 74 years  \
# 0             78614.0  ...                     6.4                     8.3
# 1             85572.0  ...                     6.0                     9.0
# 2            350738.0  ...                     4.0                     5.8
# 3            373627.0  ...                     4.5                     6.1
# 4             77056.0  ...                     4.8                     9.0
# ..                ...  ...                     ...                     ...
# 604          101639.0  ...                     3.9                     6.5
# 605          105114.0  ...                     6.0                     9.7
# 606           90642.0  ...                     7.3                     6.8
# 607           85087.0  ...                     5.4                     7.6
# 608           67009.0  ...                     7.7                     8.8
#
#      Percent 75 to 84 years  Percent 85 years and over  Violent Crimes Sum  \
# 0                       4.6                        2.0               148.0
# 1                       3.8                        2.6               168.0
# 2                       2.9                        1.6              1271.0
# 3                       2.5                        0.9              1810.0
# 4                       2.8                        1.2               299.0
# ..                      ...                        ...                 ...
# 604                     2.5                        1.5               354.0
# 605                     4.8                        1.6               260.0
# 606                     6.5                        2.6               259.0
# 607                     5.0                        1.9               213.0
# 608                     5.7                        2.2               241.0
#
#      % All Families  House Price Mean  Crime_Rate_per_100k  \
# 0               5.2          789464.7           188.261633
# 1              11.8          524186.5           196.325901
# 2              11.8          479128.8           362.378756
# 3              14.3          214306.0           484.440364
# 4              14.4          343992.4           388.029485
# ..              ...               ...                  ...
# 604             7.9          544957.1           348.291502
# 605             4.1          570472.8           247.350496
# 606            13.5          676782.2           285.739503
# 607             4.7          552625.8           250.332013
# 608            11.3          307497.6           359.653181
#
#      Percent Home Occupied  Percent Renter Occupied
# 0                44.102898                55.897102
# 1                41.495811                58.504189
# 2                43.471912                56.528088
# 3                57.775194                42.224806
# 4                54.430721                45.569279
# ..                     ...                      ...
# 604              45.724859                54.275141
# 605              57.975360                42.024640
# 606              47.216869                52.783131
# 607              60.928433                39.071567
# 608              54.540237                45.459763
#
# [609 rows x 29 columns]

# %%
all_df_reset.to_csv('All_data_cleaned.csv', index=False)
