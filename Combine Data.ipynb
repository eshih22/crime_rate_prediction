# %%
import pandas as pd
import re
from pathlib import Path

# %%
edu_data=pd.read_excel(Path("Education Level 2010-2019/Education_Data_2010_2019.xlsx"))
edu_data = edu_data.rename(columns={'Geographic Area Name': 'City'})
edu_data.head()
# Out:
#    Year          City  Population 25 years and over - Less than 9th grade  \
# 0  2010       Alameda                                               2752
# 1  2010      Alhambra                                               6236
# 2  2010       Anaheim                                              32561
# 3  2010       Antioch                                               4874
# 4  2010  Apple Valley                                                639
#
#    Percent Population 25 years and over - Less than 9th grade  \
# 0                                                5.5
# 1                                               10.1
# 2                                               15.5
# 3                                                7.7
# 4                                                1.5
#
#    Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                               2234
# 1                                               4575
# 2                                              22329
# 3                                               4633
# 4                                               3353
#
#    Percent Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                4.5
# 1                                                7.4
# 2                                               10.7
# 3                                                7.3
# 4                                                7.7
#
#    Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                               8546
# 1                                              13358
# 2                                              50982
# 3                                              17092
# 4                                              14524
#
#    Percent Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                               17.0
# 1                                               21.7
# 2                                               24.3
# 3                                               26.9
# 4                                               33.4
#
#    Population 25 years and over - Some college, no degree  \
# 0                                              10009
# 1                                              12091
# 2                                              39407
# 3                                              20113
# 4                                              11690
#
#    Percent Population 25 years and over - Some college, no degree  \
# 0                                               19.9
# 1                                               19.6
# 2                                               18.8
# 3                                               31.7
# 4                                               26.9
#
#    Population 25 years and over - Associate's degree  \
# 0                                               2894
# 1                                               5497
# 2                                              14130
# 3                                               5569
# 4                                               4802
#
#    Percent Population 25 years and over - Associate's degree  \
# 0                                                5.8
# 1                                                8.9
# 2                                                6.7
# 3                                                8.8
# 4                                               11.0
#
#    Population 25 years and over - Bachelor's degree  \
# 0                                             15544
# 1                                             13368
# 2                                             37672
# 3                                              8629
# 4                                              4582
#
#    Percent Population 25 years and over - Bachelor's degree  \
# 0                                               31.0
# 1                                               21.7
# 2                                               18.0
# 3                                               13.6
# 4                                               10.5
#
#    Population 25 years and over - Graduate or Prefessional Degree  \
# 0                                               8201
# 1                                               6442
# 2                                              12560
# 3                                               2617
# 4                                               3919
#
#    Percent Population 25 years and over - Graduate or Prefessional Degree
# 0                                               16.3
# 1                                               10.5
# 2                                                6.0
# 3                                                4.1
# 4                                                9.0

# %%
age_data=pd.read_csv(Path("Age 2010-2019/Merged_Age_2010_2019.csv"))

age_data.tail()
# Out:
#       Year         City Total population Under 5 years Percent Under 5 years  \
# 1364  2019  West Covina          105,114         6,515                 6.20%
# 1365  2019  Westminster           90,642         5,782                 6.40%
# 1366  2019     Whittier           85,087         5,514                 6.50%
# 1367  2019  Yorba Linda           67,645         3,042                 4.50%
# 1368  2019    Yuba City           67,009         3,000                 4.50%
#
#      5 to 9 years Percent 5 to 9 years 10 to 14 years Percent 10 to 14 years  \
# 1364        4,961                4.70%          6,263                  6.00%
# 1365        4,592                5.10%          6,058                  6.70%
# 1366        6,355                7.50%          5,943                  7.00%
# 1367        4,029                6.00%          4,588                  6.80%
# 1368        4,924                7.30%          4,268                  6.40%
#
#      15 to 19 years  ... 55 to 59 years Percent 55 to 59 years 60 to 64 years  \
# 1364          5,938  ...          7,093                  6.70%          6,337
# 1365          4,936  ...          4,863                  5.40%          6,589
# 1366          5,495  ...          5,510                  6.50%          4,636
# 1367          3,694  ...          5,751                  8.50%          4,263
# 1368          4,742  ...          3,286                  4.90%          5,164
#
#      Percent 60 to 64 years 65 to 74 years Percent 65 to 74 years  \
# 1364                  6.00%         10,239                  9.70%
# 1365                  7.30%          6,156                  6.80%
# 1366                  5.40%          6,432                  7.60%
# 1367                  6.30%          7,889                 11.70%
# 1368                  7.70%          5,894                  8.80%
#
#      75 to 84 years Percent 75 to 84 years 85 years and over  \
# 1364          5,011                  4.80%             1,728
# 1365          5,885                  6.50%             2,319
# 1366          4,251                  5.00%             1,658
# 1367          4,071                  6.00%               884
# 1368          3,803                  5.70%             1,502
#
#      Percent 85 years and over
# 1364                     1.60%
# 1365                     2.60%
# 1366                     1.90%
# 1367                     1.30%
# 1368                     2.20%
#
# [5 rows x 29 columns]

# %%
crime_data=pd.read_csv(Path("crime_data/crime_cleaned.csv"))

crime_data.head()
# Out:
#    Year                              City  Violent Crimes Sum
# 0  2015  Alameda Co. Sheriff's Department                 510
# 1  2015                           Alameda                 148
# 2  2015                            Albany                  34
# 3  2015                          Berkeley                 530
# 4  2015                        Emeryville                 153

# %%
income_data=pd.read_csv(Path("data_incomes_california_cities/clean_data/incomes_2010to2019.csv"))

income_data.head()
# Out:
#    Year          City  Unemployment Rate  Income
# 0  2010       Alameda               11.1   28011
# 1  2010      Alhambra                9.2   28100
# 2  2010       Anaheim               14.4  100404
# 3  2010       Antioch               15.3   30970
# 4  2010  Apple Valley               12.3   23900

# %%
poverty_data=pd.read_csv(Path("Poverty_Resources 2010-2019/All_Family_Poverty_2010_2019.csv"))

poverty_data.head()
# Out:
#    Year          City % All Families
# 0  2010       Alameda            9.6
# 1  2010      Alhambra           10.7
# 2  2010       Anaheim           12.4
# 3  2010       Antioch              8
# 4  2010  Apple Valley           10.4

# %%
house_price_data=pd.read_csv(Path("Poverty_Resources 2010-2019/Clean_House_Price_2010_2019.csv"))
house_price_data = house_price_data.rename(columns={'RegionName': 'City'})
house_price_data.head()
# Out:
#    Year          City  House price mean
# 0  2010        Acampo          289951.9
# 1  2010         Acton          355516.6
# 2  2010      Adelanto           90051.3
# 3  2010  Agoura Hills          579185.2
# 4  2010    Agua Dulce          456420.5

# %%
rent_own_data=pd.read_csv(Path("Own_vs_rent 2010-2019/rent_vs_own_cleaned 2010_2019.csv"))

rent_own_data.head()
# Out:
#    Year          City   Total Total Occupied Renter occupied
# 0  2010       Alameda   28011          13143           14868
# 1  2010      Alhambra   28100          10693           17407
# 2  2010       Anaheim  100404          48584           51820
# 3  2010       Antioch   30970          19439           11531
# 4  2010  Apple Valley   23900          16895            7005

# %%
# edu_data age_data crime_data income_data house_price_data rent_own_data
all_df = edu_data.merge(age_data, on=['City', 'Year'], how='left') \
                 .merge(crime_data, on=['City', 'Year'], how='left') \
                 .merge(income_data, on=['City', 'Year'], how='left') \
                 .merge(house_price_data, on=['City', 'Year'], how='left') \
                 .merge(poverty_data, on=['City', 'Year'], how='left') \
                 .merge(rent_own_data, on=['City', 'Year'], how='left')

# %%
all_df
# Out:
#       Year          City  Population 25 years and over - Less than 9th grade  \
# 0     2010       Alameda                                               2752
# 1     2010      Alhambra                                               6236
# 2     2010       Anaheim                                              32561
# 3     2010       Antioch                                               4874
# 4     2010  Apple Valley                                                639
# ...    ...           ...                                                ...
# 1364  2019   West Covina                                               5308
# 1365  2019   Westminster                                               8307
# 1366  2019      Whittier                                               3021
# 1367  2019   Yorba Linda                                                613
# 1368  2019     Yuba City                                               5344
#
#       Percent Population 25 years and over - Less than 9th grade  \
# 0                                                  5.50
# 1                                                 10.10
# 2                                                 15.50
# 3                                                  7.70
# 4                                                  1.50
# ...                                                 ...
# 1364                                               7.09
# 1365                                              13.03
# 1366                                               5.44
# 1367                                               1.24
# 1368                                              11.93
#
#       Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                  2234
# 1                                                  4575
# 2                                                 22329
# 3                                                  4633
# 4                                                  3353
# ...                                                 ...
# 1364                                               4530
# 1365                                               6607
# 1366                                               3921
# 1367                                               1576
# 1368                                               4756
#
#       Percent Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                  4.50
# 1                                                  7.40
# 2                                                 10.70
# 3                                                  7.30
# 4                                                  7.70
# ...                                                 ...
# 1364                                               6.05
# 1365                                              10.36
# 1366                                               7.06
# 1367                                               3.19
# 1368                                              10.62
#
#       Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                                  8546
# 1                                                 13358
# 2                                                 50982
# 3                                                 17092
# 4                                                 14524
# ...                                                 ...
# 1364                                              20919
# 1365                                              15641
# 1366                                              16232
# 1367                                               6748
# 1368                                               9396
#
#       Percent Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                                 17.00
# 1                                                 21.70
# 2                                                 24.30
# 3                                                 26.90
# 4                                                 33.40
# ...                                                 ...
# 1364                                              27.95
# 1365                                              24.53
# 1366                                              29.24
# 1367                                              13.65
# 1368                                              20.97
#
#       Population 25 years and over - Some college, no degree  \
# 0                                                 10009
# 1                                                 12091
# 2                                                 39407
# 3                                                 20113
# 4                                                 11690
# ...                                                 ...
# 1364                                              16083
# 1365                                              11273
# 1366                                              12079
# 1367                                               9289
# 1368                                              11112
#
#       Percent Population 25 years and over - Some college, no degree  ...  \
# 0                                                 19.90               ...
# 1                                                 19.60               ...
# 2                                                 18.80               ...
# 3                                                 31.70               ...
# 4                                                 26.90               ...
# ...                                                 ...               ...
# 1364                                              21.49               ...
# 1365                                              17.68               ...
# 1366                                              21.76               ...
# 1367                                              18.79               ...
# 1368                                              24.80               ...
#
#       85 years and over  Percent 85 years and over  Violent Crimes Sum  \
# 0                  1541                        2.1                 NaN
# 1                  2461                          3                 NaN
# 2                  4037                        1.2                 NaN
# 3                  1165                        1.1                 NaN
# 4                  1515                        2.2                 NaN
# ...                 ...                        ...                 ...
# 1364              1,728                      1.60%               260.0
# 1365              2,319                      2.60%               259.0
# 1366              1,658                      1.90%               213.0
# 1367                884                      1.30%                42.0
# 1368              1,502                      2.20%               241.0
#
#       Unemployment Rate    Income  House price mean % All Families   Total  \
# 0                  11.1   28011.0          605675.9            9.6   28011
# 1                   9.2   28100.0          441616.7           10.7   28100
# 2                  14.4  100404.0          371899.4           12.4  100404
# 3                  15.3   30970.0          181427.3              8   30970
# 4                  12.3   23900.0          138720.2           10.4   23900
# ...                 ...       ...               ...            ...     ...
# 1364                4.3   30682.0          570472.8            4.1  30,682
# 1365                4.5   26984.0          676782.2           13.5  26,984
# 1366                3.3   26884.0          552625.8            4.7  26,884
# 1367                1.7   22676.0          846823.6            3.5     NaN
# 1368                5.2   24393.0          307497.6           11.3  24,393
#
#      Total Occupied Renter occupied
# 0             13143           14868
# 1             10693           17407
# 2             48584           51820
# 3             19439           11531
# 4             16895            7005
# ...             ...             ...
# 1364         17,788          12,894
# 1365         12,741          14,243
# 1366         16,380          10,504
# 1367            NaN             NaN
# 1368         13,304          11,089
#
# [1369 rows x 51 columns]

# %%
all_df_clean = all_df.dropna()

# %%
all_df_reset = all_df_clean.reset_index(drop=True)

# %%
all_df_reset.dtypes
# Out:
# Year                                                                              int64
# City                                                                             object
# Population 25 years and over - Less than 9th grade                                int64
# Percent Population 25 years and over - Less than 9th grade                      float64
# Population 25 years and over - 9th to12th (No Diploma)                            int64
# Percent Population 25 years and over - 9th to12th (No Diploma)                  float64
# Population 25 years and over - High School Graduate (and equivalent)              int64
# Percent Population 25 years and over - High School Graduate (and equivalent)    float64
# Population 25 years and over - Some college, no degree                            int64
# Percent Population 25 years and over - Some college, no degree                  float64
# Population 25 years and over - Associate's degree                                 int64
# Percent Population 25 years and over - Associate's degree                       float64
# Population 25 years and over - Bachelor's degree                                  int64
# Percent Population 25 years and over - Bachelor's degree                        float64
# Population 25 years and over - Graduate or Prefessional Degree                    int64
# Percent Population 25 years and over - Graduate or Prefessional Degree          float64
# Total population                                                                 object
# Under 5 years                                                                    object
# Percent Under 5 years                                                            object
# 5 to 9 years                                                                     object
# Percent 5 to 9 years                                                             object
# 10 to 14 years                                                                   object
# Percent 10 to 14 years                                                           object
# 15 to 19 years                                                                   object
# Percent 15 to 19 years                                                           object
# 20 to 24 years                                                                   object
# Percent 20 to 24 years                                                           object
# 25 to 34 years                                                                   object
# Percent 25 to 34 years                                                           object
# 35 to 44 years                                                                   object
# Percent 35 to 44 years                                                           object
# 45 to 54 years                                                                   object
# Percent 45 to 54 years                                                           object
# 55 to 59 years                                                                   object
# Percent 55 to 59 years                                                           object
# 60 to 64 years                                                                   object
# Percent 60 to 64 years                                                           object
# 65 to 74 years                                                                   object
# Percent 65 to 74 years                                                           object
# 75 to 84 years                                                                   object
# Percent 75 to 84 years                                                           object
# 85 years and over                                                                object
# Percent 85 years and over                                                        object
# Violent Crimes Sum                                                              float64
# Unemployment Rate                                                               float64
# Income                                                                          float64
# House price mean                                                                float64
# % All Families                                                                   object
# Total                                                                            object
# Total Occupied                                                                   object
# Renter occupied                                                                  object
# dtype: object

# %%
columns_to_drop = ['Population 25 years and over - Less than 9th grade',
                   'Population 25 years and over - 9th to12th (No Diploma)',
                   'Population 25 years and over - High School Graduate (and equivalent)',
                   'Population 25 years and over - Some college, no degree',
                   "Population 25 years and over - Associate's degree",
                   "Population 25 years and over - Bachelor's degree",
                   "Population 25 years and over - Graduate or Prefessional Degree",
                   "Under 5 years",
                   "5 to 9 years",
                   "10 to 14 years",
                   "15 to 19 years",
                   "20 to 24 years",
                   "25 to 34 years",
                   "35 to 44 years",
                   "45 to 54 years",
                   "55 to 59 years", 
                   "60 to 64 years",
                   "65 to 74 years",
                   "75 to 84 years",
                   "85 years and over",
                   "Total Occupied",
                   "Renter occupied",
                   "Total",
                  ]

# %%
columns_to_convert = [
    'Total population', 'Under 5 years', 'Percent Under 5 years', 
    '5 to 9 years', 'Percent 5 to 9 years', '10 to 14 years', 
    'Percent 10 to 14 years', '15 to 19 years', 'Percent 15 to 19 years', 
    '20 to 24 years', 'Percent 20 to 24 years', '25 to 34 years', 
    'Percent 25 to 34 years', '35 to 44 years', 'Percent 35 to 44 years', 
    '45 to 54 years', 'Percent 45 to 54 years', '55 to 59 years', 
    'Percent 55 to 59 years', '60 to 64 years', 'Percent 60 to 64 years', 
    '65 to 74 years', 'Percent 65 to 74 years', '75 to 84 years', 
    'Percent 75 to 84 years', '85 years and over', 'Percent 85 years and over', 'Total', 'Total Occupied', 'Renter occupied'
]

for column in columns_to_convert:
    all_df_reset[column] = all_df_reset[column].str.replace(',|%', '', regex=True) .astype(float)

# %%
all_df_reset['Crime_Rate_per_100k'] = (all_df_reset['Violent Crimes Sum'] / all_df_reset['Total population']) * 100000
all_df_reset['Percent Home Occupied'] = all_df_reset['Total Occupied'] / all_df_reset['Total'] * 100
all_df_reset['Percent Renter Occupied'] = all_df_reset['Renter occupied'] / all_df_reset['Total'] * 100

# %%
all_df_reset
# Out:
#      Year          City  Population 25 years and over - Less than 9th grade  \
# 0    2015      Alhambra                                               5402
# 1    2015       Anaheim                                              32506
# 2    2015   Bakersfield                                              23326
# 3    2015  Baldwin Park                                              11082
# 4    2015    Bellflower                                               5350
# ..    ...           ...                                                ...
# 591  2019         Vista                                              10080
# 592  2019   West Covina                                               5308
# 593  2019   Westminster                                               8307
# 594  2019      Whittier                                               3021
# 595  2019     Yuba City                                               5344
#
#      Percent Population 25 years and over - Less than 9th grade  \
# 0                                                 8.30
# 1                                                14.40
# 2                                                10.60
# 3                                                22.10
# 4                                                11.50
# ..                                                 ...
# 591                                              15.05
# 592                                               7.09
# 593                                              13.03
# 594                                               5.44
# 595                                              11.93
#
#      Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                 4923
# 1                                                25762
# 2                                                22434
# 3                                                 6156
# 4                                                 5960
# ..                                                 ...
# 591                                               6638
# 592                                               4530
# 593                                               6607
# 594                                               3921
# 595                                               4756
#
#      Percent Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                 7.60
# 1                                                11.40
# 2                                                10.20
# 3                                                12.30
# 4                                                12.80
# ..                                                 ...
# 591                                               9.91
# 592                                               6.05
# 593                                              10.36
# 594                                               7.06
# 595                                              10.62
#
#      Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                                18760
# 1                                                53477
# 2                                                63568
# 3                                                15636
# 4                                                12421
# ..                                                 ...
# 591                                              13245
# 592                                              20919
# 593                                              15641
# 594                                              16232
# 595                                               9396
#
#      Percent Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                                28.80
# 1                                                23.60
# 2                                                28.80
# 3                                                31.10
# 4                                                26.60
# ..                                                 ...
# 591                                              19.77
# 592                                              27.95
# 593                                              24.53
# 594                                              29.24
# 595                                              20.97
#
#      Population 25 years and over - Some college, no degree  \
# 0                                                 9435
# 1                                                47633
# 2                                                46592
# 3                                                 7172
# 4                                                10068
# ..                                                 ...
# 591                                              16027
# 592                                              16083
# 593                                              11273
# 594                                              12079
# 595                                              11112
#
#      Percent Population 25 years and over - Some college, no degree  ...  \
# 0                                                14.50               ...
# 1                                                21.10               ...
# 2                                                21.10               ...
# 3                                                14.30               ...
# 4                                                21.60               ...
# ..                                                 ...               ...
# 591                                              23.93               ...
# 592                                              21.49               ...
# 593                                              17.68               ...
# 594                                              21.76               ...
# 595                                              24.80               ...
#
#      Unemployment Rate    Income  House price mean  % All Families     Total  \
# 0                  4.1   29362.0          524186.5            11.8   29362.0
# 1                  6.7   99991.0          479128.8            11.8   99991.0
# 2                 10.4  114383.0          214306.0            14.3  114383.0
# 3                  4.5   18541.0          343992.4            14.4   18541.0
# 4                  5.5   21729.0          391641.0            10.9   21729.0
# ..                 ...       ...               ...             ...       ...
# 591                4.1   31075.0          544957.1             7.9   31075.0
# 592                4.3   30682.0          570472.8             4.1   30682.0
# 593                4.5   26984.0          676782.2            13.5   26984.0
# 594                3.3   26884.0          552625.8             4.7   26884.0
# 595                5.2   24393.0          307497.6            11.3   24393.0
#
#      Total Occupied  Renter occupied  Crime_Rate_per_100k  \
# 0           12184.0          17178.0           196.325901
# 1           43468.0          56523.0           362.378756
# 2           66085.0          48298.0           484.440364
# 3           10092.0           8449.0           388.029485
# 4            8708.0          13021.0           475.559069
# ..              ...              ...                  ...
# 591         14209.0          16866.0           348.291502
# 592         17788.0          12894.0           247.350496
# 593         12741.0          14243.0           285.739503
# 594         16380.0          10504.0           250.332013
# 595         13304.0          11089.0           359.653181
#
#      Percent Home Occupied  Percent Renter Occupied
# 0                41.495811                58.504189
# 1                43.471912                56.528088
# 2                57.775194                42.224806
# 3                54.430721                45.569279
# 4                40.075475                59.924525
# ..                     ...                      ...
# 591              45.724859                54.275141
# 592              57.975360                42.024640
# 593              47.216869                52.783131
# 594              60.928433                39.071567
# 595              54.540237                45.459763
#
# [596 rows x 54 columns]

# %%
all_df_reset = all_df_reset.drop(columns=columns_to_drop, errors='ignore')

# %%
all_df_reset.dtypes
# Out:
# Year                                                                              int64
# City                                                                             object
# Percent Population 25 years and over - Less than 9th grade                      float64
# Percent Population 25 years and over - 9th to12th (No Diploma)                  float64
# Percent Population 25 years and over - High School Graduate (and equivalent)    float64
# Percent Population 25 years and over - Some college, no degree                  float64
# Percent Population 25 years and over - Associate's degree                       float64
# Percent Population 25 years and over - Bachelor's degree                        float64
# Percent Population 25 years and over - Graduate or Prefessional Degree          float64
# Total population                                                                float64
# Percent Under 5 years                                                           float64
# Percent 5 to 9 years                                                            float64
# Percent 10 to 14 years                                                          float64
# Percent 15 to 19 years                                                          float64
# Percent 20 to 24 years                                                          float64
# Percent 25 to 34 years                                                          float64
# Percent 35 to 44 years                                                          float64
# Percent 45 to 54 years                                                          float64
# Percent 55 to 59 years                                                          float64
# Percent 60 to 64 years                                                          float64
# Percent 65 to 74 years                                                          float64
# Percent 75 to 84 years                                                          float64
# Percent 85 years and over                                                       float64
# Violent Crimes Sum                                                              float64
# Unemployment Rate                                                               float64
# Income                                                                          float64
# House price mean                                                                float64
# % All Families                                                                   object
# Crime_Rate_per_100k                                                             float64
# Percent Home Occupied                                                           float64
# Percent Renter Occupied                                                         float64
# dtype: object

# %%
# List of columns to convert from 'object' to 'float64'
percentage_columns = [
    'Percent Under 5 years',
    'Percent 5 to 9 years',
    'Percent 10 to 14 years',
    'Percent 15 to 19 years',
    'Percent 20 to 24 years',
    'Percent 25 to 34 years',
    'Percent 35 to 44 years',
    'Percent 45 to 54 years',
    'Percent 55 to 59 years',
    'Percent 60 to 64 years',
    'Percent 65 to 74 years',
    'Percent 75 to 84 years',
    'Percent 85 years and over',
    '% All Families',
    'House price mean',
    'Total population'
]

# Convert each of the percentage columns to numeric type (float64)
for column in percentage_columns:
    all_df_reset[column] = pd.to_numeric(all_df_reset[column], errors='coerce')

# Check the data types again to confirm the changes
print(all_df_reset.dtypes)
# Out:
# Year                                                                              int64
# City                                                                             object
# Percent Population 25 years and over - Less than 9th grade                      float64
# Percent Population 25 years and over - 9th to12th (No Diploma)                  float64
# Percent Population 25 years and over - High School Graduate (and equivalent)    float64
# Percent Population 25 years and over - Some college, no degree                  float64
# Percent Population 25 years and over - Associate's degree                       float64
# Percent Population 25 years and over - Bachelor's degree                        float64
# Percent Population 25 years and over - Graduate or Prefessional Degree          float64
# Total population                                                                float64
# Percent Under 5 years                                                           float64
# Percent 5 to 9 years                                                            float64
# Percent 10 to 14 years                                                          float64
# Percent 15 to 19 years                                                          float64
# Percent 20 to 24 years                                                          float64
# Percent 25 to 34 years                                                          float64
# Percent 35 to 44 years                                                          float64
# Percent 45 to 54 years                                                          float64
# Percent 55 to 59 years                                                          float64
# Percent 60 to 64 years                                                          float64
# Percent 65 to 74 years                                                          float64
# Percent 75 to 84 years                                                          float64
# Percent 85 years and over                                                       float64
# Violent Crimes Sum                                                              float64
# Unemployment Rate                                                               float64
# Income                                                                          float64
# House price mean                                                                float64
# % All Families                                                                  float64
# Crime_Rate_per_100k                                                             float64
# Percent Home Occupied                                                           float64
# Percent Renter Occupied                                                         float64
# dtype: object

# %%
all_df_reset
# Out:
#      Year          City  \
# 0    2015      Alhambra
# 1    2015       Anaheim
# 2    2015   Bakersfield
# 3    2015  Baldwin Park
# 4    2015    Bellflower
# ..    ...           ...
# 591  2019         Vista
# 592  2019   West Covina
# 593  2019   Westminster
# 594  2019      Whittier
# 595  2019     Yuba City
#
#      Percent Population 25 years and over - Less than 9th grade  \
# 0                                                 8.30
# 1                                                14.40
# 2                                                10.60
# 3                                                22.10
# 4                                                11.50
# ..                                                 ...
# 591                                              15.05
# 592                                               7.09
# 593                                              13.03
# 594                                               5.44
# 595                                              11.93
#
#      Percent Population 25 years and over - 9th to12th (No Diploma)  \
# 0                                                 7.60
# 1                                                11.40
# 2                                                10.20
# 3                                                12.30
# 4                                                12.80
# ..                                                 ...
# 591                                               9.91
# 592                                               6.05
# 593                                              10.36
# 594                                               7.06
# 595                                              10.62
#
#      Percent Population 25 years and over - High School Graduate (and equivalent)  \
# 0                                                28.80
# 1                                                23.60
# 2                                                28.80
# 3                                                31.10
# 4                                                26.60
# ..                                                 ...
# 591                                              19.77
# 592                                              27.95
# 593                                              24.53
# 594                                              29.24
# 595                                              20.97
#
#      Percent Population 25 years and over - Some college, no degree  \
# 0                                                14.50
# 1                                                21.10
# 2                                                21.10
# 3                                                14.30
# 4                                                21.60
# ..                                                 ...
# 591                                              23.93
# 592                                              21.49
# 593                                              17.68
# 594                                              21.76
# 595                                              24.80
#
#      Percent Population 25 years and over - Associate's degree  \
# 0                                                 6.00
# 1                                                 6.40
# 2                                                 7.90
# 3                                                 6.30
# 4                                                 8.00
# ..                                                 ...
# 591                                               8.98
# 592                                               9.00
# 593                                               7.78
# 594                                               9.68
# 595                                               9.17
#
#      Percent Population 25 years and over - Bachelor's degree  \
# 0                                                22.90
# 1                                                17.40
# 2                                                13.90
# 3                                                10.80
# 4                                                14.70
# ..                                                 ...
# 591                                              15.94
# 592                                              20.79
# 593                                              19.52
# 594                                              15.42
# 595                                              12.69
#
#      Percent Population 25 years and over - Graduate or Prefessional Degree  \
# 0                                                11.90
# 1                                                 5.80
# 2                                                 7.50
# 3                                                 3.20
# 4                                                 4.90
# ..                                                 ...
# 591                                               6.42
# 592                                               7.62
# 593                                               7.11
# 594                                              11.39
# 595                                               9.83
#
#      Total population  ...  Percent 75 to 84 years  Percent 85 years and over  \
# 0             85572.0  ...                     3.8                        2.6
# 1            350738.0  ...                     2.9                        1.6
# 2            373627.0  ...                     2.5                        0.9
# 3             77056.0  ...                     2.8                        1.2
# 4             78434.0  ...                     3.6                        1.3
# ..                ...  ...                     ...                        ...
# 591          101639.0  ...                     2.5                        1.5
# 592          105114.0  ...                     4.8                        1.6
# 593           90642.0  ...                     6.5                        2.6
# 594           85087.0  ...                     5.0                        1.9
# 595           67009.0  ...                     5.7                        2.2
#
#      Violent Crimes Sum  Unemployment Rate    Income  House price mean  \
# 0                 168.0                4.1   29362.0          524186.5
# 1                1271.0                6.7   99991.0          479128.8
# 2                1810.0               10.4  114383.0          214306.0
# 3                 299.0                4.5   18541.0          343992.4
# 4                 373.0                5.5   21729.0          391641.0
# ..                  ...                ...       ...               ...
# 591               354.0                4.1   31075.0          544957.1
# 592               260.0                4.3   30682.0          570472.8
# 593               259.0                4.5   26984.0          676782.2
# 594               213.0                3.3   26884.0          552625.8
# 595               241.0                5.2   24393.0          307497.6
#
#      % All Families  Crime_Rate_per_100k  Percent Home Occupied  \
# 0              11.8           196.325901              41.495811
# 1              11.8           362.378756              43.471912
# 2              14.3           484.440364              57.775194
# 3              14.4           388.029485              54.430721
# 4              10.9           475.559069              40.075475
# ..              ...                  ...                    ...
# 591             7.9           348.291502              45.724859
# 592             4.1           247.350496              57.975360
# 593            13.5           285.739503              47.216869
# 594             4.7           250.332013              60.928433
# 595            11.3           359.653181              54.540237
#
#      Percent Renter Occupied
# 0                  58.504189
# 1                  56.528088
# 2                  42.224806
# 3                  45.569279
# 4                  59.924525
# ..                       ...
# 591                54.275141
# 592                42.024640
# 593                52.783131
# 594                39.071567
# 595                45.459763
#
# [596 rows x 31 columns]

# %%
all_df_reset.to_csv('All_data_cleaned.csv', index=False)
