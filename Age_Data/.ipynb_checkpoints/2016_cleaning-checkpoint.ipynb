# %%
import pandas as pd

# %%
# read file
file_path = 'Age_2016.csv'

df = pd.read_csv(file_path)

print(df)
# Out:
#                 Label (Grouping) Total population Under 5 years 5 to 9 years  \
# 0                     California              NaN           NaN          NaN
# 1                       Estimate       39,250,017     2,482,422    2,524,786
# 2                Margin of Error            *****        ±2,763      ±21,052
# 3                        Percent       39,250,017         6.30%        6.40%
# 4        Percent Margin of Error              (X)          ±0.1         ±0.1
# ..                           ...              ...           ...          ...
# 690   Yuba City city, California              NaN           NaN          NaN
# 691                     Estimate           66,837         4,765        5,047
# 692              Margin of Error              ±34          ±631       ±1,000
# 693                      Percent           66,837         7.10%        7.60%
# 694      Percent Margin of Error              (X)          ±0.9         ±1.5
#
# ...

# %%
# remoove the unwanted rows
df = df[~df['Label (Grouping)'].str.contains('Margin of Error|Percent Margin of Error', case=False)]

df
# Out:
#                Label (Grouping) Total population Under 5 years 5 to 9 years  \
# 0                    California              NaN           NaN          NaN
# 1                      Estimate       39,250,017     2,482,422    2,524,786
# 3                       Percent       39,250,017         6.30%        6.40%
# 5      Alameda city, California              NaN           NaN          NaN
# 6                      Estimate           78,907         4,520        4,777
# ..                          ...              ...           ...          ...
# 686                    Estimate           68,236         3,428        4,701
# 688                     Percent           68,236         5.00%        6.90%
# 690  Yuba City city, California              NaN           NaN          NaN
# 691                    Estimate           66,837         4,765        5,047
# 693                     Percent           66,837         7.10%        7.60%
#
# ...

# %%
# save the changes to the csv file
df.to_csv('Age_2016.csv', index=False)
print('changes saved')
# Out:
# changes saved
